# %%
import pandas as pd 
features = pd.read_csv("D:\Crop-Recommendation\soil_types_hog_features.csv")

features.head()
# Out:
#    hog_feature_0  hog_feature_1  hog_feature_2  hog_feature_3  hog_feature_4  \
# 0       0.386465       0.353553       0.377334       0.253741       0.359972
# 1       0.360709       0.371584       0.365418       0.353553       0.355501
# 2       0.371906       0.360689       0.353553       0.354259       0.362564
# 3       0.353553       0.353553       0.364424       0.353553       0.354252
# 4       0.375964       0.362986       0.353553       0.378557       0.353553
#
#    hog_feature_5  hog_feature_6  hog_feature_7  hog_feature_8  hog_feature_9  \
# 0       0.355948       0.356242       0.355576       0.373856       0.380034
# 1       0.365770       0.360635       0.363314       0.353553       0.354181
# 2       0.353553       0.353553       0.353553       0.362819       0.364634
# 3       0.356772       0.387979       0.360326       0.354027       0.353553
# 4       0.353553       0.308063       0.371288       0.353553       0.353553
#
#            label
# 0  Laterite soil
# 1  Laterite soil
# 2  Laterite soil
# 3  Laterite soil
# 4  Laterite soil

# %%
features['label'].hist()
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
x = features.drop('label', axis=1)
y = features['label']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

knn.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score

ypred = knn.predict(xtest)

print('score ', accuracy_score(ypred, ytest))
# Out:
# score  0.2413793103448276

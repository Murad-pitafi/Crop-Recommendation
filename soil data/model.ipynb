# %%
import pandas as pd
data = pd.read_excel(r'D:\Crop-Recommendation\soil data\SOIL DATA GR.xlsx')
data.head()
# Out:
#    ID  Sand %  Clay %  Silt %     pH  EC mS/cm    O.M. %  CACO3 %  N_NO3 ppm  \
# 0   1    42.0    38.0    20.0  5.162     0.274  3.783414     0.00  14.462366
# 1   2    54.0    26.0    20.0  6.071     0.355  1.451688     0.00  14.587814
# 2   3    28.0    36.0    36.0  6.921     0.675  1.767599     0.40  14.910394
# 3   4    58.0    20.0    22.0  7.704     0.355  0.718322     6.80   4.211470
# 4   5    33.2    41.2    25.6  7.609     0.392  0.996625     4.39   6.111111
#
#        P ppm  K ppm   Mg ppm  Fe ppm  Zn ppm  Mn ppm  Cu ppm  B ppm
# 0  18.608840     147    1115   91.32   0.894   27.06   1.768   0.40
# 1  32.742137     180    1055   60.04   3.660   17.58   1.684   0.41
# 2  19.024525     183    1215   61.24   3.060   18.00   1.840   0.46
# 3   6.276846     116     327   19.54   1.640    5.04   0.844   0.50
# 4   6.553970     228     939   25.84   0.180    7.16   1.216   0.40

# %%
# !pip install openpyxl

# %%
# !pip install seaborn 
# !pip install matplotlib

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for i in data.columns:
    sns.histplot(data[i], kde=True)
    plt.title(i)
    plt.show()

# %%
data.describe()
# Out:
#                ID      Sand %      Clay %      Silt %          pH    EC mS/cm  \
# count  781.000000  781.000000  781.000000  781.000000  781.000000  781.000000
# mean   391.000000   31.529321   34.997183   33.473496    7.133668    0.452793
# std    225.599572   10.978371   11.252452    8.384172    0.897823    0.304841
# min      1.000000   10.000000    6.000000   14.000000    4.490000    0.134000
# 25%    196.000000   24.000000   28.000000   28.000000    6.660000    0.338000
# 50%    391.000000   30.000000   36.000000   32.000000    7.550000    0.404000
# 75%    586.000000   38.000000   44.000000   38.000000    7.780000    0.497000
# max    781.000000   70.000000   64.000000   68.000000    8.200000    5.621000
#
#            O.M. %     CACO3 %   N_NO3 ppm       P ppm       K ppm   \
# count  781.000000  781.000000  781.000000  781.000000   781.000000
# mean     2.028909   13.422049   11.623384   13.840659   296.226633
# ...

# %%
#Area sown data 2010
data_2010 = pd.read_csv(r'D:\Crop-Recommendation\area-sown-and-production-under-cotton-crop-the-punjab-2010-20.csv')
data_2010.head()
# Out:
#       Year  Total Area Sown ("Thousand")\nHect.  Area (Thousand)\nHect.  \
# 0  2010-11                               6985.2                  2200.6
# 1  2011-12                               7383.1                  2533.7
# 2  2012-13                               7196.3                  2308.7
# 3  2013-14                               7331.8                  2199.0
# 4  2014-15                               7358.8                  2322.9
#
#    Production (Thousand)\nBales.  Index of Area Sown\n(Base year 2010-11)  \
# 0                         7854.0                                    100.0
# 1                        11129.0                                    115.1
# 2                         9526.0                                    104.9
# 3                         9145.0                                     99.9
# 4                        10277.0                                    105.6
#
#    Index of Production\n(Base year 2010-11)  % Share of Area Sown
# ...

# %%
cotton_data = pd.read_csv(r'D:\Crop-Recommendation\cotton_data.csv')
cotton_data.head()
# Out:
#   Varieties,Year of Release,Sowing Time,Yield Potential (Maunds/Acre),Recommended Areas,Salient Features,G.O.T (%),SL (mm),Mike (μg/inch),Strength (tppsi)
# 0  FH-938,2023,1st April to 31st May,40 to 50,All...
# 1  MNH-1050,2021,1st April to 31st May,40 to 50,A...
# 2  MNH-1035,2021,1st April to 31st May,40 to 50,A...
# 3  MNH-1026,2021,1st April to 31st May,40 to 50,A...
# 4  MNH-1020,2021,1st April to 31st May,40 to 50,A...

# %%
cotton_data.nunique()
# Out:
# Varieties,Year of Release,Sowing Time,Yield Potential (Maunds/Acre),Recommended Areas,Salient Features,G.O.T (%),SL (mm),Mike (μg/inch),Strength (tppsi)    66
# dtype: int64

# %%
cotton_data.tail()
# Out:
#    Varieties,Year of Release,Sowing Time,Yield Potential (Maunds/Acre),Recommended Areas,Salient Features,G.O.T (%),SL (mm),Mike (μg/inch),Strength (tppsi)
# 63  289 F/43,1934,1st May-15th June,15 to 20,All A...
# 64  LSS,1933,1st May-15th June,15 to 20,All Areas ...
# 65  4-F,1914,1st May-15th June,15 to 20,All Areas ...
# 66                                                NaN
# 67                                                NaN

# %%
cotton_data = pd.read_csv(r'D:\Crop-Recommendation\cotton_data.csv',  delimiter=';')
cotton_data.head()
# Out:
#   Varieties,Year of Release,Sowing Time,Yield Potential (Maunds/Acre),Recommended Areas,Salient Features,G.O.T (%),SL (mm),Mike (μg/inch),Strength (tppsi)
# 0  FH-938,2023,1st April to 31st May,40 to 50,All...
# 1  MNH-1050,2021,1st April to 31st May,40 to 50,A...
# 2  MNH-1035,2021,1st April to 31st May,40 to 50,A...
# 3  MNH-1026,2021,1st April to 31st May,40 to 50,A...
# 4  MNH-1020,2021,1st April to 31st May,40 to 50,A...

# %%
import pandas as pd
df =  pd.read_csv('/content/gan_data.csv')
df.head()
# Out:
#        zinc     boron  phosphorus   potassium    sulphur    Nitrogen  \
# 0 -4.984012 -6.392182   56.250959  151.243972  18.114128   43.276447
# 1 -4.980979  9.068551   80.365096  131.296510  18.219619   72.199865
# 2 -4.974066 -5.162278   80.855254  132.834931  18.152781   39.492637
# 3 -4.967354 -4.333978   81.546237  131.381773  15.127985   37.717202
# 4 -4.966512 -3.508563   72.839644  127.914555  11.408858  115.767250
#
#    Temperature yield_label
# 0    18.267161        poor
# 1    43.305149        poor
# 2    51.130021        poor
# 3    53.667639        poor
# 4    41.293378        poor

# %%
df['yield_label'].head()
# Out:
# 0    poor
# 1    poor
# 2    poor
# 3    poor
# 4    poor
# Name: yield_label, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = df.drop('yield_label',axis=1)
y=df['yield_label']

# %%
columns = x.columns
scaled_data = sc.fit_transform(x)
dfsc = pd.DataFrame(scaled_data,columns=columns)
dfsc.head()
# Out:
#        zinc     boron  phosphorus  potassium   sulphur  Nitrogen  Temperature
# 0 -2.239192 -2.237336   -0.371906   1.878505  1.259657 -1.875958    -2.196974
# 1 -2.238741  2.058906    2.366858  -0.740653  1.288075 -0.482060     1.210144
# 2 -2.237713 -1.895569    2.422528  -0.538654  1.270070 -2.058310     2.274936
# 3 -2.236716 -1.665400    2.501006  -0.729458  0.455251 -2.143873     2.620250
# 4 -2.236591 -1.436033    1.512155  -1.184713 -0.546605  1.617569     0.936386

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
prediction = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(prediction,y_test)
# Out:
# 0.7141666666666666

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(100, 50, 25), max_iter=300, solver='adam', random_state=42)
mlp.fit(x_train, y_train)

# Make predictions
y_pred = mlp.predict(x_test)

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.7975

# %%
import numpy as np
label_mapping = {'good': 1, 'poor': 0}
y_train_encoded = np.array([label_mapping[label] for label in y_train])
y_test_encoded = np.array([label_mapping[label] for label in y_test])

print("Encoded y_train:", y_train_encoded)
print("Encoded y_test:", y_test_encoded)
# Out:
# Encoded y_train: [0 0 1 ... 1 1 1]
# Encoded y_test: [1 0 1 ... 0 1 0]

# %%
import tensorflow as tf
# Build a neural network using TensorFlow
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu', input_shape=(x_train.shape[1],)),
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(25, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train_encoded, epochs=30, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
y_pred_proba = model.predict(x_test)
y_pred = (y_pred_proba > 0.5).astype(int)
#y_train_encoded = np.array([label_mapping[label] for label in y_train])
#y_test_encoded
# Calculate the accuracy
accuracy = accuracy_score(y_test_encoded, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/30
# 120/120 [==============================] - 2s 5ms/step - loss: 1.3002 - accuracy: 0.5672 - val_loss: 0.6089 - val_accuracy: 0.6562
# Epoch 2/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.6060 - accuracy: 0.6537 - val_loss: 0.5760 - val_accuracy: 0.6740
# Epoch 3/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.5741 - accuracy: 0.6816 - val_loss: 0.5472 - val_accuracy: 0.7115
# Epoch 4/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.5738 - accuracy: 0.6871 - val_loss: 0.5718 - val_accuracy: 0.6885
# Epoch 5/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.5111 - accuracy: 0.7319 - val_loss: 0.4805 - val_accuracy: 0.7479
# Epoch 6/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.5192 - accuracy: 0.7168 - val_loss: 0.4887 - val_accuracy: 0.7427
# Epoch 7/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4700 - accuracy: 0.7533 - val_loss: 0.4773 - val_accuracy: 0.7458
# Epoch 8/30
# 120/120 [==============================] - 0s 4ms/step - loss: 0.4728 - accuracy: 0.7582 - val_loss: 0.4547 - val_accuracy: 0.7708
# Epoch 9/30
# 120/120 [==============================] - 0s 4ms/step - loss: 0.4700 - accuracy: 0.7671 - val_loss: 0.4429 - val_accuracy: 0.7740
# Epoch 10/30
# 120/120 [==============================] - 1s 4ms/step - loss: 0.4685 - accuracy: 0.7504 - val_loss: 0.4575 - val_accuracy: 0.7708
# Epoch 11/30
# 120/120 [==============================] - 0s 4ms/step - loss: 0.4638 - accuracy: 0.7608 - val_loss: 0.4527 - val_accuracy: 0.7698
# Epoch 12/30
# 120/120 [==============================] - 0s 4ms/step - loss: 0.4479 - accuracy: 0.7702 - val_loss: 0.4307 - val_accuracy: 0.7812
# Epoch 13/30
# 120/120 [==============================] - 1s 5ms/step - loss: 0.4328 - accuracy: 0.7817 - val_loss: 0.4863 - val_accuracy: 0.7604
# Epoch 14/30
# 120/120 [==============================] - 0s 4ms/step - loss: 0.4240 - accuracy: 0.7874 - val_loss: 0.4483 - val_accuracy: 0.7844
# Epoch 15/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4271 - accuracy: 0.7775 - val_loss: 0.5013 - val_accuracy: 0.7552
# Epoch 16/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4345 - accuracy: 0.7733 - val_loss: 0.4510 - val_accuracy: 0.7729
# Epoch 17/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4422 - accuracy: 0.7692 - val_loss: 0.4297 - val_accuracy: 0.7833
# Epoch 18/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4420 - accuracy: 0.7738 - val_loss: 0.4161 - val_accuracy: 0.7896
# Epoch 19/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4303 - accuracy: 0.7718 - val_loss: 0.4188 - val_accuracy: 0.7885
# Epoch 20/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4317 - accuracy: 0.7804 - val_loss: 0.4399 - val_accuracy: 0.7823
# Epoch 21/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4197 - accuracy: 0.7845 - val_loss: 0.4123 - val_accuracy: 0.7927
# Epoch 22/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4067 - accuracy: 0.7837 - val_loss: 0.4116 - val_accuracy: 0.7958
# Epoch 23/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4180 - accuracy: 0.7879 - val_loss: 0.4631 - val_accuracy: 0.7531
# Epoch 24/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4102 - accuracy: 0.7921 - val_loss: 0.4137 - val_accuracy: 0.7979
# Epoch 25/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4051 - accuracy: 0.7900 - val_loss: 0.4008 - val_accuracy: 0.7990
# Epoch 26/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4114 - accuracy: 0.7804 - val_loss: 0.4076 - val_accuracy: 0.7917
# Epoch 27/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4004 - accuracy: 0.7939 - val_loss: 0.4153 - val_accuracy: 0.7823
# Epoch 28/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4005 - accuracy: 0.7918 - val_loss: 0.4153 - val_accuracy: 0.7833
# Epoch 29/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.4055 - accuracy: 0.7916 - val_loss: 0.4247 - val_accuracy: 0.7729
# Epoch 30/30
# 120/120 [==============================] - 0s 3ms/step - loss: 0.3981 - accuracy: 0.7968 - val_loss: 0.4310 - val_accuracy: 0.7927
# 38/38 [==============================] - 0s 2ms/step
# Accuracy: 0.7691666666666667
